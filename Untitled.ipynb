# %%
def add(x,y):
    return x+y

# %%
add(5,4)
# Out:
# 9

# %%
sum([5, 4, 7])
# Out:
# 16

# %%
int('6')
int('t')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-d0af8c98b9de> in <module>
#       1 int('6')
# ----> 2 int('t')
#
# ValueError: invalid literal for int() with base 10: 't'

# %%
int('6')
# Out:
# 6

# %%
int x = 5
# Out:
#   File "<ipython-input-10-d75ffed6ff63>", line 1
#     int x = 5
#         ^
# SyntaxError: invalid syntax

# %%
x = 5

# %%
x
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
x = 'sam'

# %%
type(x)
# Out:
# str

# %%
x = 9
y=6
z = 7
sum([x,y,z])
# Out:
# 22
